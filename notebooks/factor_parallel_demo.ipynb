# %% [markdown]
# # Parallel Factor Run (Modular)
#
# Compute factors in parallel, then reuse results for analytics/correlations/rolling without recomputing factors.

# %%
from datetime import date
import logging
import sys
from pathlib import Path

try:
    root = Path(__file__).resolve().parents[1]
except NameError:
    root = Path.cwd().resolve().parents[0]
if str(root) not in sys.path:
    sys.path.insert(0, str(root))

from quantlab_factor_library.run_factors import (
    compute_factors,
    run_analytics_only,
    compute_correlations_only,
    run_time_effects,
)
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# ## 1) Compute factors in parallel

# %%
# Adjust workers to your CPU/I/O; 4 is a safer default than 10
factors, ls_returns, ff, fwd_returns = compute_factors(parallel=True, max_workers=4)
print(f"Computed {len(factors)} factors; LS series: {len(ls_returns)}; FF available: {ff is not None}")
# Out:
# INFO:quantlab_factor_library.run_factors:Saved FF factors to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_ff_timeseries.parquet
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/volatility.py:20: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = prices.pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/idiosyncratic_volatility.py:20: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = prices.pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/residual_momentum.py:29: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = prices.pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/downside_vol.py:20: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = prices.pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/mean_reversion.py:19: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rev = prices.pct_change(periods=self.lookback_days)
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/amihud_illiquidity.py:23: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = price_wide.pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/amihud_illiq_log.py:23: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = price_wide.pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/amihud_illiquidity.py:23: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = price_wide.pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/efficiency_ratio.py:20: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = prices.pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/residual_vol.py:20: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = prices.pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/beta.py:20: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = prices.pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/downside_beta.py:20: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = prices.pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/piotroski_fscore.py:35: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   inc = inc.apply(pd.to_numeric, errors="ignore")
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/piotroski_fscore.py:35: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   inc = inc.apply(pd.to_numeric, errors="ignore")
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/obv.py:21: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = close.pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/hurst_exponent.py:34: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = prices.pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/skewness.py:20: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = prices.pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/kurtosis.py:20: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = prices.pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/sales_growth.py:25: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   inc["sales_growth"] = inc.groupby("ticker")["totalRevenue"].pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/asset_growth.py:24: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   bal["asset_growth"] = bal.groupby("ticker")["totalAssets"].pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/coskewness.py:20: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = prices.pct_change()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/industry_momentum.py:33: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   sector_avg = ret_sector.groupby(level=0, axis=1).mean()
# /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/quantlab_factor_library/factors/max_daily_return.py:19: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = prices.pct_change()
# INFO:quantlab_factor_library.run_factors:Saved factor momentum_12m to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_momentum_12m.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for momentum_12m to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_momentum_12m.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor volatility_60d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_volatility_60d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for volatility_60d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_volatility_60d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor residual_momentum_12m to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_residual_momentum_12m.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for residual_momentum_12m to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_residual_momentum_12m.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor ivol_60d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_ivol_60d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for ivol_60d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_ivol_60d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor downside_vol_60d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_downside_vol_60d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for downside_vol_60d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_downside_vol_60d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor mean_reversion_5d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_mean_reversion_5d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for mean_reversion_5d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_mean_reversion_5d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor high52w_proximity to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_high52w_proximity.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for high52w_proximity to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_high52w_proximity.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor dollar_volume_20d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_dollar_volume_20d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for dollar_volume_20d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_dollar_volume_20d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor amihud_illiq_20d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_amihud_illiq_20d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for amihud_illiq_20d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_amihud_illiq_20d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor amihud_illiq_log_20d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_amihud_illiq_log_20d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for amihud_illiq_log_20d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_amihud_illiq_log_20d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor amihud_illiq_252d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_amihud_illiq_252d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for amihud_illiq_252d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_amihud_illiq_252d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor efficiency_ratio_252d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_efficiency_ratio_252d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for efficiency_ratio_252d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_efficiency_ratio_252d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor profitability_roe to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_profitability_roe.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for profitability_roe to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_profitability_roe.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor size_log_mktcap to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_size_log_mktcap.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for size_log_mktcap to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_size_log_mktcap.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor earnings_yield to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_earnings_yield.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for earnings_yield to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_earnings_yield.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor residual_vol_252d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_residual_vol_252d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for residual_vol_252d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_residual_vol_252d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor cashflow_yield to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_cashflow_yield.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for cashflow_yield to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_cashflow_yield.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor dividend_yield_ttm to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_dividend_yield_ttm.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for dividend_yield_ttm to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_dividend_yield_ttm.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor beta_252d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_beta_252d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for beta_252d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_beta_252d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor downside_beta_252d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_downside_beta_252d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for downside_beta_252d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_downside_beta_252d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor free_cashflow_yield to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_free_cashflow_yield.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for free_cashflow_yield to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_free_cashflow_yield.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor gross_profitability to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_gross_profitability.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for gross_profitability to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_gross_profitability.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor rd_intensity to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_rd_intensity.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for rd_intensity to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_rd_intensity.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor accruals to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_accruals.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for accruals to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_accruals.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor net_issuance to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_net_issuance.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for net_issuance to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_net_issuance.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor net_buyback_yield to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_net_buyback_yield.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for net_buyback_yield to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_net_buyback_yield.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor investment_to_assets to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_investment_to_assets.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for investment_to_assets to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_investment_to_assets.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor piotroski_fscore to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_piotroski_fscore.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for piotroski_fscore to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_piotroski_fscore.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor obv to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_obv.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for obv to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_obv.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor atr_14d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_atr_14d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for atr_14d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_atr_14d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor hurst_252d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_hurst_252d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for hurst_252d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_hurst_252d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor vwap_dev_21d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_vwap_dev_21d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for vwap_dev_21d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_vwap_dev_21d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor benford_chi2_d1 to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_benford_chi2_d1.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for benford_chi2_d1 to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_benford_chi2_d1.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor sue to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_sue.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for sue to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_sue.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor benford_chi2_d2 to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_benford_chi2_d2.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for benford_chi2_d2 to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_benford_chi2_d2.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor dividend_growth to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_dividend_growth.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for dividend_growth to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_dividend_growth.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor skewness_60d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_skewness_60d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for skewness_60d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_skewness_60d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor ev_to_ebitda_inv to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_ev_to_ebitda_inv.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for ev_to_ebitda_inv to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_ev_to_ebitda_inv.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor kurtosis_60d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_kurtosis_60d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for kurtosis_60d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_kurtosis_60d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor roa to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_roa.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for roa to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_roa.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor book_to_price to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_book_to_price.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for book_to_price to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_book_to_price.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor leverage to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_leverage.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for leverage to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_leverage.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor analyst_revision_eps_30d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analyst_revision_eps_30d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for analyst_revision_eps_30d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_analyst_revision_eps_30d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor sales_growth to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_sales_growth.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for sales_growth to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_sales_growth.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor sales_growth_accel to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_sales_growth_accel.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for sales_growth_accel to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_sales_growth_accel.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor asset_growth to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_asset_growth.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for asset_growth to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_asset_growth.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor earnings_surprise to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_earnings_surprise.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for earnings_surprise to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_earnings_surprise.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor turnover to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_turnover.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for turnover to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_turnover.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor industry_momentum to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_industry_momentum.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for industry_momentum to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_industry_momentum.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor coskewness_252d to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_coskewness_252d.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for coskewness_252d to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_coskewness_252d.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor max_daily_return_1m to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_max_daily_return_1m.parquet
# INFO:quantlab_factor_library.run_factors:Saved LS returns for max_daily_return_1m to /Users/edl/Documents/dev/quantlab_v2/data/factors/ls_max_daily_return_1m.parquet
# Computed 51 factors; LS series: 51; FF available: True

# %% [markdown]
# ## 2) Analytics

# %%
analytics = run_analytics_only(factors, fwd_returns, ff=ff, write_registry=True)
{k: {k2: res['summary'].get(k2) for k2 in ['ls_sharpe','ls_max_drawdown','ls_sharpe_last_yr','ls_max_drawdown_last_yr']} for k,res in analytics.items()}
# Out:
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Updated factor registry at /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_analytics_summary.parquet
# INFO:quantlab_factor_library.analytics:Updated diagnostics reference registry at /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.parquet and /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_analytics_summary.csv
# INFO:quantlab_factor_library.analytics:Saved diagnostics to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_step_diagnostics.parquet
# INFO:quantlab_factor_library.analytics:Saved diagnostics reference copy to /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_step_diagnostics.parquet
# INFO:quantlab_factor_library.analytics:Saved diagnostics reference CSV to /Users/edl/Documents/dev/quantlab_v2/quantlab_factor_library/diagnostics/factor_step_diagnostics.csv
# {'momentum_12m': {'ls_sharpe': np.float64(-0.20288048382866425),
#   'ls_max_drawdown': np.float64(-0.9172728115855876),
#   'ls_sharpe_last_yr': np.float64(-0.5747597127065099),
#   'ls_max_drawdown_last_yr': np.float64(-0.24287074540656295)},
#  'volatility_60d': {'ls_sharpe': np.float64(0.8022260316858534),
#   'ls_max_drawdown': np.float64(-0.62785523080127),
#   'ls_sharpe_last_yr': np.float64(1.7063728933126825),
#   'ls_max_drawdown_last_yr': np.float64(-0.253352090183682)},
#  'residual_momentum_12m': {'ls_sharpe': np.float64(0.3549690172940553),
#   'ls_max_drawdown': np.float64(-0.7462236851281956),
#   'ls_sharpe_last_yr': np.float64(0.3229348467299529),
#   'ls_max_drawdown_last_yr': np.float64(-0.1481054976329238)},
#  'ivol_60d': {'ls_sharpe': np.float64(0.8832555128837725),
#   'ls_max_drawdown': np.float64(-0.5179214053077941),
#   'ls_sharpe_last_yr': np.float64(1.7132280767802675),
#   'ls_max_drawdown_last_yr': np.float64(-0.20877996115686337)},
#  'downside_vol_60d': {'ls_sharpe': np.float64(0.7602530836294699),
#   'ls_max_drawdown': np.float64(-0.5858196135235708),
#   'ls_sharpe_last_yr': np.float64(1.4023767891862589),
#   'ls_max_drawdown_last_yr': np.float64(-0.23444591165329398)},
#  'mean_reversion_5d': {'ls_sharpe': np.float64(1.0547213643485562),
#   'ls_max_drawdown': np.float64(-0.47866932700711706),
#   'ls_sharpe_last_yr': np.float64(0.2315329960500891),
#   'ls_max_drawdown_last_yr': np.float64(-0.1738017412777788)},
#  'high52w_proximity': {'ls_sharpe': np.float64(-0.8954379071243916),
#   'ls_max_drawdown': np.float64(-0.998720362495646),
#   'ls_sharpe_last_yr': np.float64(-0.8500189131879712),
#   'ls_max_drawdown_last_yr': np.float64(-0.32323050942705633)},
#  'dollar_volume_20d': {'ls_sharpe': np.float64(-1.5896736774066793),
#   'ls_max_drawdown': np.float64(-0.9926880175910608),
#   'ls_sharpe_last_yr': np.float64(0.1612001238768035),
#   'ls_max_drawdown_last_yr': np.float64(-0.11303610294651811)},
#  'amihud_illiq_20d': {'ls_sharpe': np.float64(1.2155641269536699),
#   'ls_max_drawdown': np.float64(-0.3396135913901551),
#   'ls_sharpe_last_yr': np.float64(2.1415633270227117),
#   'ls_max_drawdown_last_yr': np.float64(-0.09817345695109181)},
#  'amihud_illiq_log_20d': {'ls_sharpe': np.float64(1.0505615441685445),
#   'ls_max_drawdown': np.float64(-0.3087952479717807),
#   'ls_sharpe_last_yr': np.float64(1.8625450570203337),
#   'ls_max_drawdown_last_yr': np.float64(-0.09824720852581015)},
#  'amihud_illiq_252d': {'ls_sharpe': np.float64(1.0808764931311874),
#   'ls_max_drawdown': np.float64(-0.3274570177327434),
#   'ls_sharpe_last_yr': np.float64(1.2634151322223126),
#   'ls_max_drawdown_last_yr': np.float64(-0.09567446339041441)},
#  'efficiency_ratio_252d': {'ls_sharpe': np.float64(-0.15106433243665504),
#   'ls_max_drawdown': np.float64(-0.8381880996207388),
#   'ls_sharpe_last_yr': np.float64(0.04383435573194975),
#   'ls_max_drawdown_last_yr': np.float64(-0.15717298523124867)},
#  'profitability_roe': {'ls_sharpe': np.float64(-0.38743593209580496),
#   'ls_max_drawdown': np.float64(-0.7550304416794449),
#   'ls_sharpe_last_yr': np.float64(-0.9691034128098334),
#   'ls_max_drawdown_last_yr': np.float64(-0.2169372291982642)},
#  'size_log_mktcap': {'ls_sharpe': np.float64(-1.0752727553923462),
#   'ls_max_drawdown': np.float64(-0.9829780656385083),
#   'ls_sharpe_last_yr': np.float64(-0.8302564187656954),
#   'ls_max_drawdown_last_yr': np.float64(-0.3146538046660605)},
#  'earnings_yield': {'ls_sharpe': np.float64(-0.8463434343938722),
#   'ls_max_drawdown': np.float64(-0.9358376722480126),
#   'ls_sharpe_last_yr': np.float64(-0.26041246555639),
#   'ls_max_drawdown_last_yr': np.float64(-0.30962280742358617)},
#  'residual_vol_252d': {'ls_sharpe': np.float64(0.9952992758959136),
#   'ls_max_drawdown': np.float64(-0.46440479020792835),
#   'ls_sharpe_last_yr': np.float64(1.1334662622051133),
#   'ls_max_drawdown_last_yr': np.float64(-0.27996149983055507)},
#  'cashflow_yield': {'ls_sharpe': np.float64(0.03568262346174359),
#   'ls_max_drawdown': np.float64(-0.6598248394553333),
#   'ls_sharpe_last_yr': np.float64(-0.5389282191808525),
#   'ls_max_drawdown_last_yr': np.float64(-0.14990988425718)},
#  'dividend_yield_ttm': {'ls_sharpe': np.float64(0.06080726795374077),
#   'ls_max_drawdown': np.float64(-0.5804564825932308),
#   'ls_sharpe_last_yr': np.float64(-0.8212868901935675),
#   'ls_max_drawdown_last_yr': np.float64(-0.1531176976954186)},
#  'beta_252d': {'ls_sharpe': np.float64(0.23247492499274),
#   'ls_max_drawdown': np.float64(-0.7927679971879683),
#   'ls_sharpe_last_yr': np.float64(0.9411464829717721),
#   'ls_max_drawdown_last_yr': np.float64(-0.30534901444341855)},
#  'downside_beta_252d': {'ls_sharpe': np.float64(0.5905652837752884),
#   'ls_max_drawdown': np.float64(-0.5271530265656303),
#   'ls_sharpe_last_yr': np.float64(1.7177728503450747),
#   'ls_max_drawdown_last_yr': np.float64(-0.25385396494804535)},
#  'free_cashflow_yield': {'ls_sharpe': np.float64(-0.4405848240419197),
#   'ls_max_drawdown': np.float64(-0.7455075401278406),
#   'ls_sharpe_last_yr': np.float64(-1.3594442767496029),
#   'ls_max_drawdown_last_yr': np.float64(-0.2676696077626781)},
#  'gross_profitability': {'ls_sharpe': np.float64(0.2668392986014692),
#   'ls_max_drawdown': np.float64(-0.4031675998581987),
#   'ls_sharpe_last_yr': np.float64(-0.8784072896770673),
#   'ls_max_drawdown_last_yr': np.float64(-0.2552804340671816)},
#  'rd_intensity': {'ls_sharpe': np.float64(0.6167145559847076),
#   'ls_max_drawdown': np.float64(-0.2995360374399332),
#   'ls_sharpe_last_yr': np.float64(2.054335193564787),
#   'ls_max_drawdown_last_yr': np.float64(-0.13849821760961467)},
#  'accruals': {'ls_sharpe': np.float64(-0.8826198157540383),
#   'ls_max_drawdown': np.float64(-0.8405335358852953),
#   'ls_sharpe_last_yr': np.float64(-0.6368105726189196),
#   'ls_max_drawdown_last_yr': np.float64(-0.1990165006259178)},
#  'net_issuance': {'ls_sharpe': np.float64(0.4415787959549763),
#   'ls_max_drawdown': np.float64(-0.44729626205832695),
#   'ls_sharpe_last_yr': np.float64(0.02661418607208832),
#   'ls_max_drawdown_last_yr': np.float64(-0.14725067901679922)},
#  'net_buyback_yield': {'ls_sharpe': np.float64(-0.35048824336499373),
#   'ls_max_drawdown': np.float64(-0.6386496116976258),
#   'ls_sharpe_last_yr': np.float64(-0.784893592117549),
#   'ls_max_drawdown_last_yr': np.float64(-0.1963785043710755)},
#  'investment_to_assets': {'ls_sharpe': np.float64(-0.3076298082154092),
#   'ls_max_drawdown': np.float64(-0.5897031545809637),
#   'ls_sharpe_last_yr': np.float64(-0.6429029482613604),
#   'ls_max_drawdown_last_yr': np.float64(-0.07496020378765611)},
#  'piotroski_fscore': {'ls_sharpe': np.float64(0.3668706989932421),
#   'ls_max_drawdown': np.float64(-0.4023628449488488),
#   'ls_sharpe_last_yr': np.float64(-0.10864162613287091),
#   'ls_max_drawdown_last_yr': np.float64(-0.20126176888511682)},
#  'obv': {'ls_sharpe': np.float64(-0.3394335588544004),
#   'ls_max_drawdown': np.float64(-0.7342398548086453),
#   'ls_sharpe_last_yr': np.float64(-0.0977807756627582),
#   'ls_max_drawdown_last_yr': np.float64(-0.10635921344820831)},
#  'atr_14d': {'ls_sharpe': np.float64(-0.6581400837134288),
#   'ls_max_drawdown': np.float64(-0.9406115825245605),
#   'ls_sharpe_last_yr': np.float64(-1.7561717029642603),
#   'ls_max_drawdown_last_yr': np.float64(-0.33059371178590646)},
#  'hurst_252d': {'ls_sharpe': np.float64(0.516462134436145),
#   'ls_max_drawdown': np.float64(-0.36427834539186277),
#   'ls_sharpe_last_yr': np.float64(1.0593836746774596),
#   'ls_max_drawdown_last_yr': np.float64(-0.07358816718797845)},
#  'vwap_dev_21d': {'ls_sharpe': np.float64(-0.8203837493788344),
#   'ls_max_drawdown': np.float64(-0.9951103173682495),
#   'ls_sharpe_last_yr': np.float64(-0.22841522836760955),
#   'ls_max_drawdown_last_yr': np.float64(-0.21974002043278018)},
#  'benford_chi2_d1': {'ls_sharpe': np.float64(0.31866185064601504),
#   'ls_max_drawdown': np.float64(-0.13681215230868304),
#   'ls_sharpe_last_yr': np.float64(0.005983616098019407),
#   'ls_max_drawdown_last_yr': np.float64(-0.0440975451476151)},
#  'sue': {'ls_sharpe': np.float64(-0.09418222900368199),
#   'ls_max_drawdown': np.float64(-0.6113897433429523),
#   'ls_sharpe_last_yr': np.float64(0.42985504523236534),
#   'ls_max_drawdown_last_yr': np.float64(-0.10098582980812165)},
#  'benford_chi2_d2': {'ls_sharpe': np.float64(0.39461105461276935),
#   'ls_max_drawdown': np.float64(-0.2499896898972569),
#   'ls_sharpe_last_yr': np.float64(0.876432149004356),
#   'ls_max_drawdown_last_yr': np.float64(-0.02762395534349571)},
#  'dividend_growth': {'ls_sharpe': np.float64(-0.21304407448384757),
#   'ls_max_drawdown': np.float64(-0.6423360616103655),
#   'ls_sharpe_last_yr': np.float64(-0.09680348886159033),
#   'ls_max_drawdown_last_yr': np.float64(-0.06795338642574256)},
#  'skewness_60d': {'ls_sharpe': np.float64(0.5023311524333198),
#   'ls_max_drawdown': np.float64(-0.385853071873441),
#   'ls_sharpe_last_yr': np.float64(0.5270882031734705),
#   'ls_max_drawdown_last_yr': np.float64(-0.11707398858980289)},
#  'ev_to_ebitda_inv': {'ls_sharpe': np.float64(0.20538263873252047),
#   'ls_max_drawdown': np.float64(-0.49444861929878314),
#   'ls_sharpe_last_yr': np.float64(0.02848661241124267),
#   'ls_max_drawdown_last_yr': np.float64(-0.18506429701593285)},
#  'kurtosis_60d': {'ls_sharpe': np.float64(0.4821300152370382),
#   'ls_max_drawdown': np.float64(-0.28135845590678366),
#   'ls_sharpe_last_yr': np.float64(0.6826855991909514),
#   'ls_max_drawdown_last_yr': np.float64(-0.048250082952817186)},
#  'roa': {'ls_sharpe': np.float64(-0.6789956018097933),
#   'ls_max_drawdown': np.float64(-0.9128059041288562),
#   'ls_sharpe_last_yr': np.float64(-1.165229453526377),
#   'ls_max_drawdown_last_yr': np.float64(-0.39120157678366163)},
#  'book_to_price': {'ls_sharpe': np.float64(0.43553933385269256),
#   'ls_max_drawdown': np.float64(-0.4523462805103312),
#   'ls_sharpe_last_yr': np.float64(1.3585723349199512),
#   'ls_max_drawdown_last_yr': np.float64(-0.11073068490353588)},
#  'leverage': {'ls_sharpe': np.float64(0.13390170262194417),
#   'ls_max_drawdown': np.float64(-0.3127471093249553),
#   'ls_sharpe_last_yr': np.float64(0.03619593533101558),
#   'ls_max_drawdown_last_yr': np.float64(-0.10563611289233532)},
#  'analyst_revision_eps_30d': {'ls_sharpe': np.float64(9.540322157776124),
#   'ls_max_drawdown': np.float64(-0.006393232827078155),
#   'ls_sharpe_last_yr': np.float64(9.540322157776124),
#   'ls_max_drawdown_last_yr': np.float64(-0.006393232827078155)},
#  'sales_growth': {'ls_sharpe': np.float64(0.30131420097811784),
#   'ls_max_drawdown': np.float64(-0.37011503117507116),
#   'ls_sharpe_last_yr': np.float64(0.7101746506826074),
#   'ls_max_drawdown_last_yr': np.float64(-0.1563905512067505)},
#  'sales_growth_accel': {'ls_sharpe': np.float64(0.11117054411890023),
#   'ls_max_drawdown': np.float64(-0.3978596042347925),
#   'ls_sharpe_last_yr': np.float64(-0.16373481203620588),
#   'ls_max_drawdown_last_yr': np.float64(-0.13405860090320287)},
#  'asset_growth': {'ls_sharpe': np.float64(-0.19025766665741328),
#   'ls_max_drawdown': np.float64(-0.5273649730227883),
#   'ls_sharpe_last_yr': np.float64(-0.725499478732047),
#   'ls_max_drawdown_last_yr': np.float64(-0.20344297793144805)},
#  'earnings_surprise': {'ls_sharpe': np.float64(-0.04338097548702218),
#   'ls_max_drawdown': np.float64(-0.9209718652851374),
#   'ls_sharpe_last_yr': np.float64(-1.8543700672191366),
#   'ls_max_drawdown_last_yr': np.float64(-0.7813050540856188)},
#  'turnover': {'ls_sharpe': np.float64(0.03562662369938933),
#   'ls_max_drawdown': np.float64(-0.5389368207355119),
#   'ls_sharpe_last_yr': np.float64(1.1492326696259199),
#   'ls_max_drawdown_last_yr': np.float64(-0.21654657542927325)},
#  'industry_momentum': {'ls_sharpe': np.float64(-0.3383252874824757),
#   'ls_max_drawdown': np.float64(-0.8434669999724516),
#   'ls_sharpe_last_yr': np.float64(0.35026142114806647),
#   'ls_max_drawdown_last_yr': np.float64(-0.157983945650497)},
#  'coskewness_252d': {'ls_sharpe': np.float64(-0.605162131273131),
#   'ls_max_drawdown': np.float64(-0.9672875962921481),
#   'ls_sharpe_last_yr': np.float64(0.40009911300841805),
#   'ls_max_drawdown_last_yr': np.float64(-0.1274286983384254)},
#  'max_daily_return_1m': {'ls_sharpe': np.float64(0.8227987340875025),
#   'ls_max_drawdown': np.float64(-0.49942590923239005),
#   'ls_sharpe_last_yr': np.float64(1.2290669730300126),
#   'ls_max_drawdown_last_yr': np.float64(-0.22129756309425075)}}

# %% [markdown]
# ## 3) Correlations

# %%
corr_paths = compute_correlations_only(factors, ls_returns=ls_returns, ff=ff)
corr_paths
# Out:
# INFO:quantlab_factor_library.analytics:Saved factor correlation matrix to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_correlation.parquet
# INFO:quantlab_factor_library.run_factors:Saved factor vs FF correlation to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_ff_correlation.parquet
# (PosixPath('/Users/edl/Documents/dev/quantlab_v2/data/factors/factor_correlation.parquet'),
#  PosixPath('/Users/edl/Documents/dev/quantlab_v2/data/factors/factor_ff_correlation.parquet'))

# %% [markdown]
# ## 4) Rolling time effects

# %%
rolling = run_time_effects(factors, fwd_returns, window=252, step=21)
rolling.head() if not rolling.empty else "No rolling stats"
# Out:
# INFO:quantlab_factor_library.run_factors:Saved rolling analytics to /Users/edl/Documents/dev/quantlab_v2/data/factors/factor_rolling_analytics.parquet
#          factor        date  rolling_mean_ic  rolling_ic_ir
# 0  momentum_12m  2002-02-08         0.015233       0.111731
# 1  momentum_12m  2002-03-12         0.012520       0.089192
# 2  momentum_12m  2002-04-11         0.013509       0.098703
# 3  momentum_12m  2002-05-10         0.020592       0.158410
# 4  momentum_12m  2002-06-11         0.022781       0.176176
